# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/titanic_me.csv")

# %%
df.head()

# %%
df.info()

# %%
df.drop(columns=['PassengerId'],inplace=True)

# %%
df.Survived.value_counts()

# %%
df.Pclass.value_counts()

# %%
df.drop(columns=['Name'],inplace=True)

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
df.Sex.dtype

# %%
df.Age.describe()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.histplot(df['Age'], kde=True, color='blue')
plt.title('Distribution of Age')
plt.show()

# %%
df.Age = df.Age.fillna(df.Age.median())

# %%
# 2. Boxplot to identify outliers
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['Age'], color='red')
plt.title('Boxplot of Age (Check for Outliers)')
plt.show()

# %%
# binning Age
bins = [0, 12, 18, 60, 100]
labels = ['Child', 'Teenager', 'Adult', 'Senior']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[['Child', 'Teenager', 'Adult', 'Senior']])


df['AgeGroup_Encoded'] = encoder.fit_transform(df[['AgeGroup']])

# %%
df.drop(columns=['AgeGroup'],inplace=True)

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1


df['IsAlone'] = 0  # Initialize the column
df.loc[df['FamilySize'] == 1, 'IsAlone'] = 1

# %%
df.FamilySize.value_counts()

# %%
df.IsAlone.value_counts()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='IsAlone', y='Survived', data=df)
plt.title('Survival Rate: Alone (1) vs. With Family (0)')
plt.show()
