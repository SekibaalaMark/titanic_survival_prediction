# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/titanic_me.csv")

# %%
df.head()

# %%
df.info()

# %%
df.drop(columns=['PassengerId'],inplace=True)

# %%
df.Survived.value_counts()

# %%
df.Pclass.value_counts()

# %%
df.drop(columns=['Name'],inplace=True)
